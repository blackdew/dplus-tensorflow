# %% [markdown]
# # 01. Python Basic 01
#
# <p style="text-align: right;">
# blackdew7@gmail.com<br>
# </p>
#
# ### 파이썬 실습시간 그 첫번째!
# 전체 교육 과정에서 파이썬을 사용합니다.
#
# #### 실습목표
# 1. 데이터 타입을 알고 있다. - 숫자, 문자, boolean
# 2. 제어문을 사용할 수 있고, 제어문이 사용된 소스코드를 이해할 수 있다.
# 3. 리스트(List)를 이해하고, 리스트가 사용된 소스코드를 이해할 수 있다. 리스트를 사용할 수 있다.
# 5. 함수(Function)가 무엇인지 알고, 함수가 사용된 소스코드를 이해할 수 있다. 간단한 함수를 작성할 수 있다.

# %% [markdown]
# ## Jupyter Notebook 단축키
# * Cell 실행: Control + Enter
# * Cell 실행 + 다음셀 이동: Shift + Enter
# * Code Completion: Tab
# * Tooltip 보기: Shift + Tab
# * 셀 생성 & 삭제: A (셀을 선택된 셀 위에 생성), B (셀을 선택된 셀 아래에 생성), D (선택된 셀을 삭제)
# * 줄 번호 보기: L
# * Command Palette 보기: Shift + Control/Command + P
# * 단축키 모음 보기: H

# %% [markdown]
# ## Magic 키워드
# * Jupyter Notebook은 사용자 편의를 위해 Magic 키워드 를 지원한다.
# * Magic 키워드는 % 또는 %%를 이용하여 실행할 수 있다. 각각 한 줄, 한 셀에 대해 Magic 키워드를 실행한다.
# * Magic 키워드로 제공하는 기능은 여러가지가 있지만 주로 사용되는것은 다음과 같다.

# %%
# 메모리를 리셋한다.
# %reset

# matplot 그래프와 그림을 출력한다.
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# 파일을 로딩한다. 
# %load

# %% [markdown]
# # 01 파이썬 기초 문법
#
# 1. hello python
# 2. Variables
# 3. Type & Operator - Number
# 4. Type & Operator - String
# 5. Container - List
# 6. Slicing

# %% [markdown]
# ## 1. Hello Python

# %%
print("Hello, Python World!!") 

# !주의 
# 2.0 버전에서는 '()' 괄호가 없는 형태로 print문을 처리할 수 있었습니다. 
# 3.0 버전에서 python 코드를 들고와서 돌렸는데 에러가 날 때에는 print 처리가 어떻게 되어있는지 확인해 봐야해요. 
# print "Hello, Python World!!"

# %%
# help '?' 이용, or Shift + Tab
# ?print

# %% [markdown]
# ## 2. Variables
#
# - 대소문자 구분함.
# - 알파벳 + 숫자 및 언더바
# - 변수 이름으로 변수에 담긴 값을 소환
# - 다중 할당

# %%
# 학점 규칙: 중간고사 40%, 기말고사 40%, 퀴즈 20%

# 변수 할당
midterm = 95
finals = 65
quiz = 90

result = midterm * 0.4 + finals * 0.4 + quiz * 0.2
print(result)

# 다중 할당
midterm, finals, quiz = 95, 65, 90

# %% [markdown]
# ## 3. Type & Operator - Number
#
# - number: int, float
# - 산술 연산자

# %%
# 학점 규칙: 중간고사 40%, 기말고사 40%, 퀴즈 20%

midterm, finals, quiz = 95, 65, 90
result = midterm * 0.4 + finals * 0.4 + quiz * 0.2
print(result)

# int
print(type(midterm))

# float
print(type(result))

# 수리 연산자
# +, -, *, /
# %
# **
# //
# +=, -=, *=, /=

# %% [markdown]
# ## 4. Type & Operator - String
#
# - string
# - print 활용
# - string slicing

# %%
# 문자열
# 파이썬은 문자열에 대해 상당한 편의성을 지원합니다.

thanks = 'thanks'    # 작은 따옴표를 사용할 수 있습니다.
name = "Guido van Rossum"    # 큰 따옴표도 사용할 수 있습니다.
tn = thanks + ' ' + name  # 문자열 연결

# print
print(thanks)       # "thanks" 출력.
print(len(thanks))  # 문자열 길이 출력 - "5"
print(tn)  # "thanks Guido van Rossum" 출력

# multi line string
multilines = """
hello, python world
- Guido van Rossum
- python.org
"""

# 문자열 출력 활용 1
print("%s %s" % (thanks, name))

# 문자열 출력 활용 2
print("{0} {1} {0} {1}".format(thanks, name))

# %% [markdown]
# ## 5. Container - List
#
# - list
# - add & remove

# %%
# stu01 - name, midterm, finals, quiz = "Geoffery Hinton", 95, 65, 90
# stu02 - name, midterm, finals, quiz = "Yann Lecun", 80, 85, 90
# stu03 - name, midterm, finals, quiz = "Yoshua Bengio", 92, 88, 84
# stu04 - name, midterm, finals, quiz = "Andrew Ng", 75, 85, 100

# 리스트 생성
stu01 = ["Geoffery Hinton", 95, 65, 90]
stu02 = ["Yann Lecun", 80, 85, 90]
stu03 = ["Yoshua Bengio", 92, 88, 84]
stu04 = ["Andrew Ng", 75, 85, 100]

print(type(stu01))

# 리스트 요소 조회
stu01[0]
stu01[3]


# 2차원 리스트
stu = [stu01, stu02, stu03, stu04]
print(type(stu01))

# 2차원 리스트 요소 조회
stu[0][0]

# %%
# stu01 - name, midterm, finals, quiz = "Geoffery Hinton", 95, 65, 90
# stu02 - name, midterm, finals, quiz = "Yann Lecun", 80, 85, 90
# stu03 - name, midterm, finals, quiz = "Yoshua Bengio", 92, 88, 84
# stu04 - name, midterm, finals, quiz = "Andrew Ng", 75, 85, 100

# 리스트 생성
stu01 = ["Geoffery Hinton", 95, 65, 90]
stu02 = ["Yann Lecun", 80, 85, 90]
stu03 = ["Yoshua Bengio", 92, 88, 84]
stu04 = ["Andrew Ng", 75, 85, 100]

print(type(stu01))

## 요소 추가하기 
stu01.append(100)

## 요소 제거하기 
del stu01[0]

## 요소 변경하기
stu01[0] = 99

## 리스트 복제
stu05 = stu01[:]
stuu06 = stu01.copy()

# %% [markdown]
# ## 6. Slicing
# - slicing list
# - slicing string

# %%
# 리스트 생성
numbers = [95, 65, 90, 80, 85, 90, 92, 88, 84, 75, 85, 100]

# 리스트의 subset 01
print(numbers[0:3])
print(numbers[3:6])
print(numbers[6:9])
print(numbers[9:12])

# 리스트의 subset 02
print(numbers[:3])

# 리스트의 subset 03
print(numbers[9:])

# %%
# 문자열 생성
python = "hobby project during the week around Christmas as his office was closed"

# 문자열 subset 01
print(python[0:5])
print(python[6:13])

# 문자열 subset 02
print(python[:5])

# 문자열 subset 03
print(python[6:])

# %% [markdown]
# ### 실습

# %%
# 각 리스트의 요소는 name, midterm, quiz, finals입니다. 
stu01 = ["Geoffery Hinton", 95, 65, 90]
stu02 = ["Yann Lecun", 80, 85, 90]
stu03 = ["Yoshua Bengio", 92, 88, 84]
stu04 = ["Andrew Ng", 75, 85, 100]

# 위의 4개의 리스트를 담은 stu 리스트를 생성하세요. 
stu = [stu01, stu02, stu03, stu04]


# 각 학생들의 이름 중 Last Name만 출력하시오.
print(stu01[0][-6:])
print(stu02[0][-5:])
print(stu03[0][-6:])
print(stu04[0][-2:])

# 각 학생들의 학기 합산 점수를 구하세요. 
# result = midterm * 0.4 + finals * 0.4 + quiz * 0.2
stu01_avg = stu01[1] * 0.4 + stu01[2] * 0.2 + stu01[3] * 0.4
stu02_avg = stu02[1] * 0.4 + stu02[2] * 0.2 + stu02[3] * 0.4
stu03_avg = stu03[1] * 0.4 + stu03[2] * 0.2 + stu03[3] * 0.4
stu04_avg = stu04[1] * 0.4 + stu04[2] * 0.2 + stu04[3] * 0.4

# stu 리스트에 위에서 구한 합산 점수를 추가 하세요. 
stu01.append(stu01_avg)
stu02.append(stu02_avg)
stu03.append(stu03_avg)
stu04.append(stu04_avg)

# 다음의  활용하여 이름과 합산 점수를 출력하세요. 
email = """
Hello, {0}

{0}의 이번학기 성적은 {1}입니다.

수고하셨습니다. 

"""
print(email.format(stu01[0], stu01[4]))

# 학생들의 midterm, quiz, finals 요소만 slicing 해서 mqf list에 추가하는 구문을 완성하세요.
mqf = []
mqf.append(stu[0][1:4])
mqf.append(stu[1][1:4])
mqf.append(stu[2][1:4])
mqf.append(stu[3][1:4])
print(mqf)

# %% [markdown]
# # 02 파이썬 입문 I
#
# 1. Type & Operator - Boolean
# 2. Control (제어문)
# 3. Function (함수)
# 4. Method
# 5. Package

# %% [markdown]
# ## 1. Type & Operator - Boolean
#
# - boolean
# - 비교 연산자

# %%
# True/False Boolean

t = True
f = False
print(type(t)) # Prints "<class 'bool'>"

# 논리 연산자
print(t and f) # AND 연산, "False"
print(t or f)  # OR 연산, "True"
print(not t)   # NOT 연산, prints "False"

# 비교 연산자
# ==, !=, >, <, >=, <=

# %% [markdown]
# ## 2. Control (제어문)
#
# - 조건문: if-else
# - 반복문: while
# - 반복문: for

# %%
# 조건문 - if-else

my_score = 73
 
if my_score >= 90:
    my_grade = 'A'
elif my_score >= 80:
    my_grade = 'B'
elif my_score >= 70:
    my_grade = 'C'
elif my_score >= 60:
    my_grade = 'E'
else:
    my_grade = 'F'
 
print(my_grade)

# %%
# 반복문 - for
for i in range(5):
    print(i)
    
for i in range(5):
    print('*', end='')

fruits = ['apple', 'banana', 'cherry']
 
for i in fruits:
    print(i)
    
for index, value in enumerate(fruits):
    print(index, value)

# %%
# 반복문 - while
fruits = ['apple', 'banana', 'cherry']
i = 0 
while i < len(fruits):
    print(fruits[i])
    i += 1

# %% [markdown]
# ### 실습

# %%
for j in range(5):
    for i in range(4):
        print('*', end='')
    print()

    
# 위의 코드를 변형하여 다음 모양을 출력해보자

# 1. 
# *
# **
# ***
# ****
# *****
for j in range(5):
    for i in range(j + 1):
        print('*', end='')
    print()

# 2. 
# *****
# ****
# ***
# **
# *
for j in range(5):
    for i in range(5 - j):
        print('*', end='')
    print()
    
# 3.
#     *
#    **
#   ***
#  ****
# *****
for j in range(5):
    for i in range(5 - j):
        print(' ', end='')
    for i in range(j + 1):
        print('*', end='')
    print()
    
# 각 리스트의 요소는 name, midterm, quiz, finals입니다. 
stu = [["Geoffery Hinton", 95, 65, 90],
       ["Yann Lecun", 80, 85, 90],
       ["Yoshua Bengio", 92, 88, 84],
       ["Andrew Ng", 75, 85, 100]]

# 학점 규칙: 중간고사 35%, 기말고사 35%, 퀴즈 30%
# total을 계산하는 함수를 생성하시오. 
def total(midterm, finals, quiz):
    r = midterm * 0.35 + finals * 0.35 + quiz * 0.3
    return r

# 점수에 해당하는 grade를 반환하는 함수를 만드시오. 
# 90이상 A, 80이상 B, 70 이상 C, 나머지는 F
def grade(total):
    if (total >= 90):
        g = 'A'
    elif (total >= 80):
        g = 'B'
    elif (total >= 70):
        g = 'B'
    else:
        g = 'F'
    return g

# for문을 이용하여 stu 모든 학생들의 total 결과를 totals list에 차례로 담으세요. 
totals = []
for s in stu:
    totals.append(total(s[1], s[2], s[3]))
    
totals

# %% [markdown]
# ## 3. Function (함수)
#
# - 내장 함수: print, round, max, min, sorted
# - 함수 만들기

# %%
print("I love you")

# 아래의 문장을 출력해보자.
# 1. He said "I'll be back"
# 2. the file's directory is "C:\\Python3"

# %%
print(round(10.4607))
print(round(10.5129))
print(round(10.5129, 2))
print(round(10.5029, 3))

numbers = [95, 65, 90, 80, 85, 90, 92, 88, 84, 75, 85, 100]
print(max(numbers))
print(min(numbers))
print(sorted(numbers))

# help
help(print)

# %%
# os 모듈
import os

print(os.getcwd())
print(os.listdir())

# %%
def sign(x):
    if x > 0:
        return 'positive'
    elif x < 0:
        return 'negative'
    else:
        return 'zero'

for x in [-1, 0, 1]:
    print(sign(x))

# %%
def total(midterm, quiz, finals):
    return midterm * 0.4 + quiz * 0.2 + finals * 0.4

stu01 = ["Geoffery Hinton", 95, 65, 90]
stu02 = ["Yann Lecun", 80, 85, 90]
stu03 = ["Yoshua Bengio", 92, 88, 84]
stu04 = ["Andrew Ng", 75, 85, 100]

print(total(stu01[1], stu01[2], stu01[3]))

# 파이썬 함수 특징

#1 - 여러 개의 value return
print(total(*stu01[1:4]))

#2 여러 개의 value return
def total2(s):
    result = s[1] * 0.4 + s[2] * 0.2 + s[3] * 0.4
    return s[0], result

print(total2(stu01))

# %% [markdown]
# ### 실습

# %%
# 1. 두 개의 정수 값을 받아 평균을 구하는 함수를 작성하세요.
def get_average(x, y):
    # 함수구현
    return (x + y) / 2

# 2. 리스트를 입력받아서 최소값과 최대값을 반환하는 함수를 작성하세요.
def get_min(ls):
    # 함수구현
    r = ls[0]
    for e in ls:
        if (r > e):
            r = e
    return r
    
def get_max(ls):
    # 함수구현
    r = ls[0]
    for e in ls:
        if (r < e): 
            r = e
    return r

# 3. 시작과 끝 숫자를 받아 시작부터 끝까지의 모든 정수값의 합을 반환하는 함수를 작성하세요. (시작값과 끝값 포함)
def get_sum(start, end):
    # 함수구현
    r = []
    for i in range(end - start + 1):
        r.append(i + start)
    return r

print(get_average(3, 5))
print(get_min([1, 2, 3, 4, 5]))
print(get_max([1, 2, 3, 4, 5]))
print(get_sum(3, 5))

# %% [markdown]
# ## 4. Method
#
# - list의 metnods
# - string의 methods
# - 'dir': object의 methods 확인

# %%
numbers = [95, 65, 90, 80, 85, 90, 92, 88, 84, 75, 85, 100]
print(numbers)

print(numbers.index(65))

numbers.remove(65)
print(numbers)

numbers.sort()
print(numbers)

numbers.clear()
print(numbers)

# %%
hello = "hello, guido van Rossum "
print(hello)

print(hello.capitalize())
print(hello.upper())
print(hello.lower())
print(hello.replace('hello', 'goodbyeindexindex'))

# %%
hello = ""
print(type(hello))
print(dir(hello))

numbers = []
print(type(numbers))
print(dir(numbers))

# %%
# 1. string object의 strip 메쏘드가 무엇인지 알아보고 사용해보자.
print(" test ".strip())

# 2. string object의 split 메쏘드가 무엇인지 알아보고 알아보고 사용해보자.
print("1, 2, 3, 4, 5, 6".split(','))

# 3. string object의 join 메쏘드가 무엇인지 알아보고 알아보고 사용해보자.
print(",".join(["a", "b", "c"]))

# 4. list object의 insert 메쏘드가 무엇인지 알아보고 사용해보자. append와 어떤 차이가 있는지 설명해보자.
a = [1, 2, 3, 4, 5]
a.append(6)
a.insert(3, 3.5)
print(a)

# 5. list object의 pop 메쏘드가 무엇인지 알아보고 사용해보자.
print(a.pop())
print(a)

numbers = [95, 65, 90, 80, 85, 90, 92, 88, 84, 75, 85, 100]
# 6. numbers의 요소가 몇개인지 구하시오.
print(len(numbers))

# 7. numbers를 역순으로 정렬하시오
print(numbers)
print(sorted(numbers, reverse=True))

names = "    guido van Rossum     "
# 8. names 문자열의 길이를 구하시오
print(len(names))

# 9. names 앞 뒤 공백을 재거하고 출력하시오
print(names)
print(names.strip())

# %% [markdown]
# ## 5. Package
#
# - install package
# - import package

# %%
# !pip install package
# !pip3 install package

# %%
import requests

# HTTP GET Request
req = requests.get('http://info.cern.ch/')

print(req.text)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(req.text, 'html.parser')

print(soup)
